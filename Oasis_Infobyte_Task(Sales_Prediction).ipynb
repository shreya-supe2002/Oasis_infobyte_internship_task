# %%
# IMPORTING LIBRARIES

import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Load the data

dataset_sales=pd.read_csv(r"C:\Users\one\Downloads\Advertising.csv")
dataset_sales.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
# Visualization of dataset (stats)

dataset_sales.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
dataset_sales.shape
# Out:
# (200, 5)

# %%
dataset_sales.columns.values.tolist()
# Out:
# ['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales']

# %%
# Basic information about data types

dataset_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
# Preprocessing ( Checking for null values)

dataset_sales.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
dataset_sales.duplicated().sum()
# Out:
# 0

# %%
sns.countplot(x='Sales',data=dataset_sales)
plt.show()

# %%
sns.pairplot(hue='Sales',height=2,data=dataset_sales)
# Out:
# C:\Users\one\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\one\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\one\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\one\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\one\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
dataset_sales.corr()
# Out:
#             Unnamed: 0        TV     Radio  Newspaper     Sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# Radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# Newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# Sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
sns.heatmap(dataset_sales.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(dataset_sales,kind="reg",corner=True)

# %%
fig, axs =plt.subplots(3,figsize=(5,5))
plt1 = sns.boxplot(dataset_sales['TV'], ax= axs[0])
plt2 = sns.boxplot(dataset_sales['Newspaper'], ax= axs[1])
plt3 = sns.boxplot(dataset_sales['Radio'], ax= axs[2])
plt.tight_layout()
# Out:
# C:\Users\one\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\one\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\one\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.displot(dataset_sales['Newspaper'])

# %%
iqr=dataset_sales.Newspaper.quantile(0.75)-dataset_sales.Newspaper.quantile(0.25)
lower=dataset_sales["Newspaper"].quantile(0.25)-(iqr*1.5)
upper=dataset_sales["Newspaper"].quantile(0.75)+(iqr*1.5)
print(lower)
print(upper)
# Out:
# -35.775000000000006
# 93.625

# %%
data=dataset_sales.copy()

# %%
X= data['TV']
Y= data['Sales']

# %%
X=X.values.reshape(-1,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-134b44b9a337> in <module>
# ----> 1 X=X.values.reshape(-1,1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
X
# Out:
# array([[230.1],
#        [ 44.5],
#        [ 17.2],
#        [151.5],
#        [180.8],
#        [  8.7],
#        [ 57.5],
#        [120.2],
#        [  8.6],
#        [199.8],
#        [ 66.1],
#        [214.7],
#        [ 23.8],
#        [ 97.5],
#        [204.1],
#        [195.4],
#        [ 67.8],
#        [281.4],
#        [ 69.2],
#        [147.3],
#        [218.4],
#        [237.4],
#        [ 13.2],
#        [228.3],
#        [ 62.3],
#        [262.9],
#        [142.9],
#        [240.1],
#        [248.8],
#        [ 70.6],
#        [292.9],
#        [112.9],
#        [ 97.2],
#        [265.6],
#        [ 95.7],
#        [290.7],
#        [266.9],
#        [ 74.7],
#        [ 43.1],
#        [228. ],
#        [202.5],
#        [177. ],
#        [293.6],
#        [206.9],
#        [ 25.1],
#        [175.1],
#        [ 89.7],
#        [239.9],
#        [227.2],
#        [ 66.9],
#        [199.8],
#        [100.4],
#        [216.4],
#        [182.6],
#        [262.7],
# ...

# %%
print(X.shape,Y.shape)
# Out:
# (200, 1) (200,)

# %%
# splitting data for training and testing

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,test_size=0.3)

# %%
print(X_train.shape,Y_train.shape)
# Out:
# (140, 1) (140,)

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.neighbors import KNeighborsRegressor

# %%
knn =KNeighborsRegressor().fit(X_train,Y_train)
knn
# Out:
# KNeighborsRegressor()

# %%
knn_train_pred=knn.predict(X_train)
knn_test_pred=knn.predict(X_test)
print(knn_train_pred,knn_test_pred)
# Out:
# [17.34 15.12  8.64 11.56 15.66 13.22 13.22 13.82 15.92 19.98 15.14 11.56
#  20.8  15.54 12.48 19.58 15.48 17.26  5.58 10.34 18.7  10.2   5.58 16.32
#  16.32 10.36 14.68  9.8  16.14  7.24 11.56  7.02 18.7  16.74 16.74 14.82
#  18.9  11.5   9.44  5.58 10.76 13.76 16.32  9.38 17.58 17.58 15.04 15.76
#   9.34 17.4   7.24 14.88 19.24  9.34  9.72 17.    6.06  6.06 19.32 15.66
#   9.18 19.98  7.24 16.74 15.92  5.58 19.94 15.04 14.86 19.98  8.64 11.38
#  19.96  8.64 11.5   8.26 18.9  10.28 14.2  14.2  21.04 17.7  13.22 14.34
#  10.34 11.54 13.94  4.84 13.04 10.34 15.28 10.5  17.78 11.56 11.5  12.24
#  15.1  19.24 16.04 14.68 10.36 14.68 16.74 16.32  8.64 16.62 15.1  14.88
#   7.02 19.24 13.22 11.8  10.2  17.1  20.8  16.62 19.98 12.56 11.56  9.72
#   7.02 21.04  8.72 16.62 15.9  17.26 19.98 14.92 20.68 17.4  14.66 19.32
#  15.28 20.48 15.54 14.88 10.2  19.24 14.88 16.74] [15.54  7.02 14.    7.24 12.56 10.36 15.66 14.88 16.74 17.1  14.6  18.04
# ...

# %%
r2= r2_score(Y_test,knn_test_pred)
r2_train = r2_score(Y_train,knn_train_pred)
rmse= np.sqrt(mean_squared_error(Y_test,knn_test_pred))
varience= r2_train -r2

print("K-Nearest Neighbors")
print("R2 TRAIN : ",r2_train)
print("R2 : ",r2)
print("RMSE : ",rmse)
print("VARIENCE : ",varience)
# Out:
# K-Nearest Neighbors
# R2 TRAIN :  0.6797096768912984
# R2 :  0.5308063518569632
# RMSE :  3.76560575029658
# VARIENCE :  0.14890332503433512

# %%
import statsmodels.api as sm

X_train_constant = sm.add_constant(X_train)
model = sm.OLS(Y_train, X_train_constant).fit()
model.params
# Out:
# const    7.155489
# x1       0.045751
# dtype: float64

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.582
# Model:                            OLS   Adj. R-squared:                  0.579
# Method:                 Least Squares   F-statistic:                     192.1
# Date:                Tue, 28 Feb 2023   Prob (F-statistic):           6.53e-28
# Time:                        19:12:46   Log-Likelihood:                -364.81
# No. Observations:                 140   AIC:                             733.6
# Df Residuals:                     138   BIC:                             739.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.1555      0.560     12.773      0.000       6.048       8.263
# ...

# %%
plt.scatter(X_train, Y_train)
plt.plot(X_train,6.995+0.0541*X_train)
plt.show()

# %%
Y_train_pred= model.predict(X_train_constant)
result= (Y_train - Y_train_pred)
result
# Out:
# 128    7.465459
# 105    5.735381
# 12     0.955626
# 86     1.353673
# 64     4.846492
#          ...
# 50    -4.896635
# 34    -2.033906
# 35    -7.655445
# 96    -4.495982
# 21    -5.516891
# Name: Sales, Length: 140, dtype: float64

# %%
Y_train_pred
# Out:
# array([17.23454092, 13.46461856,  8.24437414, 10.64632709, 13.15350846,
#        12.66854273, 12.69141847, 15.25350162, 17.33061903, 19.17440387,
#        17.55022616, 10.57312472, 18.76721566, 17.77440844, 12.17900184,
#        18.28224992, 17.60055279, 16.79532666,  7.51235038, 11.74893788,
#        20.24041347, 11.55678164,  7.53980127, 14.73193469, 14.63585657,
#        11.29142303, 13.62017361, 11.46527867, 13.34108955,  7.94241434,
#        10.65090224,  8.0430676 , 20.16263595, 18.14042032, 18.14042032,
#        15.04761994, 17.11558705, 10.28489036,  9.44306304,  7.54895157,
#         9.1273778 , 13.69337599, 14.68160806,  9.8822773 , 19.81492466,
#        20.02995664, 15.1665738 , 17.884212  ,  9.72672225, 15.61493835,
#         7.92868889, 16.26460944, 20.55609872,  9.78619918,  9.36528552,
#        15.50970994,  7.7594084 ,  7.75483325, 17.15218824, 13.18095936,
#         8.59666057, 19.30708318,  7.97444038, 18.13127002, 17.33061903,
# ...

# %%
figure= plt.figure()
sns.displot(result)
plt.show()

# %%
plt.scatter(X_train,result)
plt.show()

# %%
X_test_constant = sm.add_constant(X_test)
Y_pred = model.predict(X_test_constant)
Y_pred
# Out:
# array([17.65545458,  8.01104157, 12.90645045,  7.94241434, 12.46266104,
#        11.19534491, 13.29991322, 16.25545914, 18.05349249, 15.99467568,
#        13.38684104, 18.21362269,  8.96267245, 16.49336686, 17.58682735,
#        20.13060991, 18.10381913, 10.60057561, 10.38554363,  7.55352672,
#         9.12280265, 17.48617408,  8.41365463, 19.82407496, 16.91885567,
#        18.53845823, 16.42016448, 17.21166517, 16.5345432 ,  9.20058017,
#        12.17900184, 16.61689587, 11.45155323, 11.25939699, 19.9979306 ,
#        10.51364779,  8.90319552, 10.21626314, 20.31361585, 20.71622891,
#        15.25350162, 19.97505486, 15.74761766, 19.18355417, 13.53782094,
#         7.40254682, 16.19598221, 10.00580631, 13.52409549,  7.69078117,
#        18.12669487, 11.60253313,  7.34306989, 17.01035864, 10.59142531,
#        11.85416629, 10.25743947, 12.22017817, 16.79990181, 10.82475788])

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
np.sqrt(mean_squared_error(Y_test,Y_pred))
# Out:
# 3.1828833170103716

# %%
r2= r2_score(Y_test,Y_pred)
r2
# Out:
# 0.6647846766471028

# %%
plt.scatter(X_test,Y_test)
plt.plot(X_test, 6.9955 + 0.0541*X_test)
plt.show()
